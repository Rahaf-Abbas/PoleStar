# %%
import pandas as pd


ratings = pd.read_csv('Books.csv')

# %%
ratings.head()
# Out:
#                                            book_name  \
# 0                  Intel Galileo Networking Cookbook
# 1                  OpenVPN Cookbook - Second Edition
# 2                            Troubleshooting OpenVPN
# 3  OpenVPN:  Building and Integrating Virtual Pri...
# 4                       Getting Started with MariaDB
#
#                                           book_image                 author  \
# 0  www.packtpub.com/media/catalog/product/cache/5...      By Marco Schwartz
# 1  www.packtpub.com/media/catalog/product/cache/5...    By Jan Just Keijser
# 2  www.packtpub.com/media/catalog/product/cache/5...        By Eric F Crist
# 3  www.packtpub.com/media/catalog/product/cache/5...      By Markus Feilner
# 4  www.packtpub.com/media/catalog/product/cache/5...  By Daniel Bartholomew
#
#    page                                  short_description  \
# 0   174  Over 50 recipes that will help you use the Int...
# 1   400  Discover over 90 practical and exciting recipe...
# 2   178  Get the solutions you need to troubleshoot any...
# 3   270  Learn how to build secure VPNs using this powe...
# 4   100  MariaDB is growing in popularity as a “drop-in...
#
#   programming_language                  concept     tool  ratings  user_id
# 0                   C#               Networking  Galileo        5        0
# 1                   C#               Networking  OpenVPN        5        0
# 2                   C#               Networking  OpenVPN        1      196
# 3                   C#               Networking  OpenVPN        3      186
# 4                  C++  Database Administration  MariaDB        3       22

# %%
bookRatings = ratings.pivot_table(index=['user_id'],columns=['book_name'],values='ratings')
bookRatings[156:166]

#pivot_table function on a DataFrame will construct a user / book rating matrix
# Out:
# book_name  AJAX and PHP: Building Modern Web Applications 2nd Edition  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      NaN
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  AJAX and PHP: Building Responsive Web Applications  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      5.0
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  AJAX y PHP: Construyendo Aplicaciones Web Interactivas [Espanol]  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      NaN
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  AMP: Building Accelerated Mobile Pages  \
# user_id
# 156                                           NaN
# 157                                           NaN
# 158                                           NaN
# 159                                           NaN
# 160                                           NaN
# 161                                           NaN
# 162                                           NaN
# 163                                           NaN
# 164                                           NaN
# 165                                           NaN
#
# book_name  ASP.NET Core 2 and Angular 5  ASP.NET Core and Angular 2  \
# user_id
# 156                                 NaN                         NaN
# 157                                 NaN                         NaN
# 158                                 NaN                         NaN
# 159                                 NaN                         NaN
# 160                                 NaN                         NaN
# 161                                 NaN                         NaN
# 162                                 NaN                         NaN
# 163                                 NaN                         NaN
# 164                                 NaN                         NaN
# 165                                 NaN                         NaN
#
# book_name  AWS Certified Machine Learning Specialty: MLS-C01 Certification Guide  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      NaN
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  Advanced Deep Learning with Keras  \
# user_id
# 156                                      NaN
# 157                                      NaN
# 158                                      NaN
# 159                                      NaN
# 160                                      NaN
# 161                                      NaN
# 162                                      NaN
# 163                                      NaN
# 164                                      NaN
# 165                                      NaN
#
# book_name  Advanced Deep Learning with Python  Advanced Deep Learning with R  \
# user_id
# 156                                       NaN                            NaN
# 157                                       NaN                            NaN
# 158                                       NaN                            NaN
# 159                                       NaN                            NaN
# 160                                       NaN                            NaN
# 161                                       NaN                            NaN
# 162                                       NaN                            NaN
# 163                                       NaN                            NaN
# 164                                       NaN                            NaN
# 165                                       NaN                            NaN
#
# book_name  ...  jQuery UI 1.6: The User Interface Library for jQuery  \
# user_id    ...
# 156        ...                                                NaN
# 157        ...                                                NaN
# 158        ...                                                NaN
# 159        ...                                                NaN
# 160        ...                                                NaN
# 161        ...                                                NaN
# 162        ...                                                NaN
# 163        ...                                                NaN
# 164        ...                                                NaN
# 165        ...                                                NaN
#
# book_name  jQuery UI 1.7: The User Interface Library for jQuery  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      NaN
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  jQuery UI 1.8: The User Interface Library for jQuery  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      5.0
# 160                                                      NaN
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  jQuery UI Cookbook  jQuery UI Themes Beginner's Guide  \
# user_id
# 156                       NaN                                3.0
# 157                       NaN                                NaN
# 158                       NaN                                NaN
# 159                       NaN                                NaN
# 160                       NaN                                NaN
# 161                       NaN                                NaN
# 162                       NaN                                NaN
# 163                       NaN                                NaN
# 164                       NaN                                NaN
# 165                       NaN                                NaN
#
# book_name  jQuery for Designers Beginner's Guide Second Edition  \
# user_id
# 156                                                      NaN
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      NaN
# 161                                                      NaN
# 162                                                      NaN
# 163                                                      NaN
# 164                                                      NaN
# 165                                                      NaN
#
# book_name  jQuery for Designers: Beginner's Guide  scikit-learn Cookbook  \
# user_id
# 156                                           NaN                    NaN
# 157                                           NaN                    NaN
# 158                                           NaN                    NaN
# 159                                           NaN                    NaN
# 160                                           NaN                    NaN
# 161                                           NaN                    NaN
# 162                                           NaN                    NaN
# 163                                           NaN                    NaN
# 164                                           NaN                    NaN
# 165                                           NaN                    NaN
#
# book_name  scikit-learn Cookbook - Second Edition  \
# user_id
# 156                                           NaN
# 157                                           NaN
# 158                                           NaN
# 159                                           NaN
# 160                                           NaN
# 161                                           NaN
# 162                                           NaN
# 163                                           NaN
# 164                                           NaN
# 165                                           NaN
#
# book_name  scikit-learn: Machine Learning Simplified
# user_id
# 156                                              NaN
# 157                                              NaN
# 158                                              NaN
# 159                                              NaN
# 160                                              NaN
# 161                                              NaN
# 162                                              NaN
# 163                                              NaN
# 164                                              NaN
# 165                                              NaN
#
# [10 rows x 1157 columns]

# %%
#users who rated book & entering input (book to search for similarity):
input = "OpenVPN Cookbook - Second Edition"
x = bookRatings[input]
x[1:20]
# Out:
# user_id
# 1     5.0
# 2     3.0
# 3     NaN
# 4     NaN
# 5     NaN
# 6     4.0
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    5.0
# 12    NaN
# 13    4.0
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: OpenVPN Cookbook - Second Edition, dtype: float64

# %%
# corrwith function makes it really easy to compute the pairwise correlation
# Showing the relation between the books and other books based on rating
 
similarBooks = bookRatings.corrwith(x)
similarBooks = similarBooks.dropna()
df = pd.DataFrame(similarBooks)
df.head()
# Out:
# D:\anaconda3\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# D:\anaconda3\lib\site-packages\numpy\lib\function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                                            0
# book_name
# AJAX and PHP: Building Responsive Web Applications  0.239046
# AJAX y PHP: Construyendo Aplicaciones Web Inter... -0.505035
# ASP.NET Core 2 and Angular 5                        0.500000
# ASP.NET Core and Angular 2                         -1.000000
# Advanced Java EE Development with WildFly           1.000000

# %%
# Getting the Similar Books according to the rating and users

similarBooks.sort_values(ascending=False)
# Out:
# book_name
# PostgreSQL 9.0 High Performance                                                                     1.0
# Instant E-commerce with OpenCart: Build a Shop                                                      1.0
# History Teaching with Moodle 2                                                                      1.0
# Node Cookbook: Second Edition                                                                       1.0
# Drupal Web Services                                                                                 1.0
#                                                                                                    ...
# Elasticsearch Server: Second Edition                                                               -1.0
# Drupal: Creating Blogs, Forums, Portals, and Community Websites                                    -1.0
# TensorFlow Machine Learning Cookbook                                                               -1.0
# Apache Solr Search Patterns                                                                        -1.0
# Learning jQuery: Better Interaction Design and Web Development with Simple JavaScript Techniques   -1.0
# Length: 589, dtype: float64

# %%
# get rid of the unpopluar books who may mess up our results (missing more rating).
# counts up how many ratings exist for each book and the average rate.


import numpy as np
BookStats = ratings.groupby('book_name').agg({'ratings': [np.size, np.mean]})

# %%
#get rid of any books rated by fewer than 40 people, and check the top-rated ones that are left

popularBooks = BookStats['ratings']['size'] >= 40
BookStats[popularBooks].sort_values([('ratings', 'mean')], ascending=False)[:15]

print(popularBooks)
# Out:
# book_name
# AJAX and PHP: Building Modern Web Applications 2nd Edition          False
# AJAX and PHP: Building Responsive Web Applications                  False
# AJAX y PHP: Construyendo Aplicaciones Web Interactivas [Espanol]    False
# AMP: Building Accelerated Mobile Pages                              False
# ASP.NET Core 2 and Angular 5                                        False
#                                                                     ...
# jQuery for Designers Beginner's Guide Second Edition                False
# jQuery for Designers: Beginner's Guide                              False
# scikit-learn Cookbook                                               False
# scikit-learn Cookbook - Second Edition                              False
# scikit-learn: Machine Learning Simplified                           False
# Name: size, Length: 1157, dtype: bool

# %%
# Applying the new List of books (has 40 rating at least) to results
df = BookStats[popularBooks].join(pd.DataFrame(similarBooks, columns=['similarity']))
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_20212\4088160253.py:2: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   df = BookStats[popularBooks].join(pd.DataFrame(similarBooks, columns=['similarity']))

# %%
df.head()
# Out:
#                                                     (ratings, size)  \
# book_name
# Alfresco Developer Guide                                         45
# Android Studio 3.5 Development Essentials - Jav...               85
# Android Studio 3.5 Development Essentials - Kot...               79
# Android Studio Cookbook                                          83
# Android Wearable Programming                                     49
#
#                                                     (ratings, mean)  \
# book_name
# Alfresco Developer Guide                                   3.666667
# Android Studio 3.5 Development Essentials - Jav...         3.552941
# Android Studio 3.5 Development Essentials - Kot...         3.620253
# Android Studio Cookbook                                    3.433735
# Android Wearable Programming                               3.816327
#
#                                                     similarity
# book_name
# Alfresco Developer Guide                              0.386683
# Android Studio 3.5 Development Essentials - Jav...    0.141229
# Android Studio 3.5 Development Essentials - Kot...   -0.246528
# Android Studio Cookbook                               0.026803
# Android Wearable Programming                          0.582926

# %%
# taking Top 3 books based on similarity for our specfied book (input best match) 
results = df.sort_values(['similarity'], ascending=False)[1:4]

# %%
#printing the recommended books to the user
firstBook = results[:1].index[0]
SecondBook = results[1:2].index[0]
ThirdBook = results[2:3].index[0]

print("First Book:" , firstBook)
print("Second Book:" , SecondBook)
print("Third Book:" , ThirdBook)
# Out:
# First Book: Android Wearable Programming
# Second Book: SAP HANA Cookbook
# Third Book: Hands-On Exploratory Data Analysis with R
